# %%
import cv2
import numpy as np
import os

# %%
def extract_rice_grains(image, save_folder, image_name):
    os.makedirs(save_folder, exist_ok=True)

    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    lower_white = np.array([0, 0, 140])
    upper_white = np.array([180, 80, 255])

    mask = cv2.inRange(hsv, lower_white, upper_white)

    kernel = np.ones((3,3), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=1)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=1)

    contours, _ = cv2.findContours(
        mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
    )

    grain_id = 0

    for cnt in contours:
        area = cv2.contourArea(cnt)

        if 15 < area < 2500:
            x, y, w, h = cv2.boundingRect(cnt)

            # Add padding
            pad = 5
            x1 = max(x - pad, 0)
            y1 = max(y - pad, 0)
            x2 = min(x + w + pad, image.shape[1])
            y2 = min(y + h + pad, image.shape[0])

            crop = image[y1:y2, x1:x2]

            #  Resize to 128x128
            resized = cv2.resize(crop, (128, 128))

            # Save image
            filename = f"{image_name}_grain_{grain_id}.png"
            save_path = os.path.join(save_folder, filename)

            cv2.imwrite(save_path, resized)

            grain_id += 1

    return grain_id

# %%
def extract_from_folder(input_folder, output_folder):
    total_grains = 0

    os.makedirs(output_folder, exist_ok=True)

    image_files = sorted([
        f for f in os.listdir(input_folder)
        if f.endswith(('.png', '.jpg', '.jpeg'))
    ])

    for img_name in image_files:
        img_path = os.path.join(input_folder, img_name)

        image = cv2.imread(img_path)
        if image is None:
            continue

        name_without_ext = os.path.splitext(img_name)[0]

        count = extract_rice_grains(
            image,
            output_folder,
            name_without_ext
        )

        total_grains += count

        print(f"{img_name}: {count} grains extracted")

    print("\nTotal extracted grains:", total_grains)

# %%
input_folder = "original_frames"
output_folder = "rice_grains_dataset"

extract_from_folder(input_folder, output_folder)
# Out:
# frame_00000.jpg: 0 grains extracted
# frame_00001.jpg: 0 grains extracted
# frame_00002.jpg: 0 grains extracted
# frame_00003.jpg: 1 grains extracted
# frame_00004.jpg: 0 grains extracted
# frame_00005.jpg: 0 grains extracted
# frame_00006.jpg: 0 grains extracted
# frame_00007.jpg: 0 grains extracted
# frame_00008.jpg: 0 grains extracted
# frame_00009.jpg: 0 grains extracted
# frame_00010.jpg: 0 grains extracted
# frame_00011.jpg: 0 grains extracted
# frame_00012.jpg: 0 grains extracted
# frame_00013.jpg: 0 grains extracted
# frame_00014.jpg: 0 grains extracted
# frame_00015.jpg: 0 grains extracted
# frame_00016.jpg: 0 grains extracted
# frame_00017.jpg: 0 grains extracted
# frame_00018.jpg: 0 grains extracted
# frame_00019.jpg: 0 grains extracted
# frame_00020.jpg: 0 grains extracted
# frame_00021.jpg: 0 grains extracted
# frame_00022.jpg: 0 grains extracted
# frame_00023.jpg: 0 grains extracted
# frame_00024.jpg: 0 grains extracted
# frame_00025.jpg: 0 grains extracted
# ...
