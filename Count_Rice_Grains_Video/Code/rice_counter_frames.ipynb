# %%
import cv2
import numpy as np
import os

# %%
def count_rice_grains(image):
    output = image.copy()

    # Convert to HSV
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Expanded white range (captures dim rice too)
    lower_white = np.array([0, 0, 140])   # ↓ reduced from 180 → 140
    upper_white = np.array([180, 80, 255]) # ↑ saturation tolerance

    mask1 = cv2.inRange(hsv, lower_white, upper_white)

    #  Extra: detect slightly gray rice (very useful)
    lower_gray = np.array([0, 0, 100])
    upper_gray = np.array([180, 60, 200])

    mask2 = cv2.inRange(hsv, lower_gray, upper_gray)

    # Combine both
    mask = cv2.bitwise_or(mask1, mask2)

    # Morphology
    kernel = np.ones((3,3), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=2)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=2)

    contours, _ = cv2.findContours(
        mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
    )

    rice_count = 0

    for cnt in contours:
        area = cv2.contourArea(cnt)

        if 40 < area < 5500:
            rice_count += 1
            x, y, w, h = cv2.boundingRect(cnt)
            cv2.rectangle(output, (x,y), (x+w, y+h), (0,255,0), 2)

    return rice_count, output, mask

# %%
def process_and_save(folder_path, output_folder):
    total_count = 0

    # Create output folders
    detected_folder = os.path.join(output_folder, "detected")
    mask_folder = os.path.join(output_folder, "mask")

    os.makedirs(detected_folder, exist_ok=True)
    os.makedirs(mask_folder, exist_ok=True)

    image_files = sorted([
        f for f in os.listdir(folder_path)
        if f.endswith(('.png', '.jpg', '.jpeg'))
    ])

    for img_name in image_files:
        img_path = os.path.join(folder_path, img_name)

        image = cv2.imread(img_path)
        if image is None:
            continue

        count, output, mask = count_rice_grains(image)
        total_count += count

        print(f"{img_name}: {count} grains")

        # Save detected image
        detected_path = os.path.join(detected_folder, img_name)
        cv2.imwrite(detected_path, output)

        # Save mask image
        mask_path = os.path.join(mask_folder, img_name)
        cv2.imwrite(mask_path, mask)

    print("\nTotal rice grains from all images:", total_count)

    return total_count

# %%
input_folder = "original_frames"
output_folder = "original_output_frames"

total = process_and_save(input_folder, output_folder)
# Out:
# frame_00000.jpg: 0 grains
# frame_00001.jpg: 0 grains
# frame_00002.jpg: 0 grains
# frame_00003.jpg: 0 grains
# frame_00004.jpg: 0 grains
# frame_00005.jpg: 0 grains
# frame_00006.jpg: 0 grains
# frame_00007.jpg: 0 grains
# frame_00008.jpg: 0 grains
# frame_00009.jpg: 0 grains
# frame_00010.jpg: 0 grains
# frame_00011.jpg: 0 grains
# frame_00012.jpg: 0 grains
# frame_00013.jpg: 0 grains
# frame_00014.jpg: 0 grains
# frame_00015.jpg: 0 grains
# frame_00016.jpg: 0 grains
# frame_00017.jpg: 0 grains
# frame_00018.jpg: 0 grains
# frame_00019.jpg: 0 grains
# frame_00020.jpg: 0 grains
# frame_00021.jpg: 0 grains
# frame_00022.jpg: 0 grains
# frame_00023.jpg: 0 grains
# frame_00024.jpg: 0 grains
# frame_00025.jpg: 0 grains
# frame_00026.jpg: 0 grains
# frame_00027.jpg: 0 grains
# frame_00028.jpg: 0 grains
# frame_00029.jpg: 0 grains
# frame_00030.jpg: 0 grains
# frame_00031.jpg: 0 grains
# frame_00032.jpg: 0 grains
# frame_00033.jpg: 0 grains
# frame_00034.jpg: 0 grains
# frame_00035.jpg: 0 grains
# frame_00036.jpg: 0 grains
# frame_00037.jpg: 0 grains
# frame_00038.jpg: 0 grains
# frame_00039.jpg: 0 grains
# frame_00040.jpg: 0 grains
# frame_00041.jpg: 0 grains
# frame_00042.jpg: 0 grains
# frame_00043.jpg: 0 grains
# frame_00044.jpg: 0 grains
# frame_00045.jpg: 0 grains
# frame_00046.jpg: 1 grains
# frame_00047.jpg: 1 grains
# frame_00048.jpg: 2 grains
# frame_00049.jpg: 12 grains
# frame_00050.jpg: 13 grains
# frame_00051.jpg: 3 grains
# frame_00052.jpg: 5 grains
# frame_00053.jpg: 4 grains
# frame_00054.jpg: 6 grains
# frame_00055.jpg: 3 grains
# frame_00056.jpg: 1 grains
# frame_00057.jpg: 8 grains
# frame_00058.jpg: 7 grains
# frame_00059.jpg: 3 grains
# frame_00060.jpg: 4 grains
# frame_00061.jpg: 1 grains
# frame_00062.jpg: 4 grains
# frame_00063.jpg: 1 grains
# frame_00064.jpg: 1 grains
# frame_00065.jpg: 8 grains
# frame_00066.jpg: 9 grains
# frame_00067.jpg: 6 grains
# frame_00068.jpg: 1 grains
# frame_00069.jpg: 3 grains
# frame_00070.jpg: 6 grains
# frame_00071.jpg: 0 grains
# frame_00072.jpg: 0 grains
# frame_00073.jpg: 3 grains
# frame_00074.jpg: 8 grains
# frame_00075.jpg: 3 grains
# frame_00076.jpg: 3 grains
# frame_00077.jpg: 1 grains
# frame_00078.jpg: 6 grains
# frame_00079.jpg: 2 grains
# frame_00080.jpg: 0 grains
# frame_00081.jpg: 1 grains
# frame_00082.jpg: 7 grains
# frame_00083.jpg: 6 grains
# frame_00084.jpg: 3 grains
# frame_00085.jpg: 2 grains
# frame_00086.jpg: 1 grains
# frame_00087.jpg: 1 grains
# frame_00088.jpg: 2 grains
# frame_00089.jpg: 0 grains
# frame_00090.jpg: 10 grains
# frame_00091.jpg: 8 grains
# frame_00092.jpg: 5 grains
# frame_00093.jpg: 0 grains
# frame_00094.jpg: 2 grains
# frame_00095.jpg: 3 grains
# frame_00096.jpg: 1 grains
# frame_00097.jpg: 0 grains
# frame_00098.jpg: 14 grains
# frame_00099.jpg: 6 grains
# frame_00100.jpg: 7 grains
# frame_00101.jpg: 0 grains
# frame_00102.jpg: 4 grains
# frame_00103.jpg: 2 grains
# frame_00104.jpg: 5 grains
# frame_00105.jpg: 2 grains
# frame_00106.jpg: 7 grains
# frame_00107.jpg: 16 grains
# frame_00108.jpg: 2 grains
# frame_00109.jpg: 3 grains
# frame_00110.jpg: 3 grains
# frame_00111.jpg: 6 grains
# frame_00112.jpg: 3 grains
# frame_00113.jpg: 2 grains
# frame_00114.jpg: 8 grains
# frame_00115.jpg: 9 grains
# frame_00116.jpg: 5 grains
# frame_00117.jpg: 4 grains
# frame_00118.jpg: 3 grains
# frame_00119.jpg: 2 grains
# frame_00120.jpg: 1 grains
# frame_00121.jpg: 0 grains
# frame_00122.jpg: 7 grains
# frame_00123.jpg: 11 grains
# frame_00124.jpg: 6 grains
# frame_00125.jpg: 4 grains
# frame_00126.jpg: 3 grains
# frame_00127.jpg: 2 grains
# frame_00128.jpg: 0 grains
# frame_00129.jpg: 2 grains
# frame_00130.jpg: 9 grains
# frame_00131.jpg: 12 grains
# frame_00132.jpg: 6 grains
# frame_00133.jpg: 4 grains
# frame_00134.jpg: 3 grains
# frame_00135.jpg: 4 grains
# frame_00136.jpg: 1 grains
# frame_00137.jpg: 4 grains
# frame_00138.jpg: 8 grains
# frame_00139.jpg: 3 grains
# frame_00140.jpg: 1 grains
# frame_00141.jpg: 7 grains
# frame_00142.jpg: 1 grains
# frame_00143.jpg: 6 grains
# frame_00144.jpg: 6 grains
# frame_00145.jpg: 5 grains
# frame_00146.jpg: 4 grains
# frame_00147.jpg: 0 grains
# frame_00148.jpg: 8 grains
# frame_00149.jpg: 6 grains
# frame_00150.jpg: 2 grains
# frame_00151.jpg: 0 grains
# frame_00152.jpg: 3 grains
# frame_00153.jpg: 1 grains
# frame_00154.jpg: 5 grains
# frame_00155.jpg: 5 grains
# frame_00156.jpg: 4 grains
# frame_00157.jpg: 1 grains
# frame_00158.jpg: 1 grains
# frame_00159.jpg: 2 grains
# frame_00160.jpg: 4 grains
# frame_00161.jpg: 1 grains
# frame_00162.jpg: 2 grains
# frame_00163.jpg: 0 grains
# frame_00164.jpg: 2 grains
# frame_00165.jpg: 1 grains
# frame_00166.jpg: 5 grains
# frame_00167.jpg: 2 grains
# frame_00168.jpg: 1 grains
# frame_00169.jpg: 0 grains
# frame_00170.jpg: 1 grains
# frame_00171.jpg: 11 grains
# frame_00172.jpg: 2 grains
# frame_00173.jpg: 2 grains
# frame_00174.jpg: 3 grains
# frame_00175.jpg: 6 grains
# frame_00176.jpg: 1 grains
# frame_00177.jpg: 5 grains
# frame_00178.jpg: 3 grains
# frame_00179.jpg: 0 grains
# frame_00180.jpg: 0 grains
# frame_00181.jpg: 0 grains
# frame_00182.jpg: 2 grains
# frame_00183.jpg: 1 grains
# frame_00184.jpg: 1 grains
# frame_00185.jpg: 0 grains
# frame_00186.jpg: 1 grains
# frame_00187.jpg: 0 grains
# frame_00188.jpg: 6 grains
# frame_00189.jpg: 4 grains
# frame_00190.jpg: 4 grains
# frame_00191.jpg: 0 grains
# frame_00192.jpg: 0 grains
# frame_00193.jpg: 1 grains
# frame_00194.jpg: 3 grains
# frame_00195.jpg: 2 grains
# frame_00196.jpg: 0 grains
# frame_00197.jpg: 2 grains
# frame_00198.jpg: 0 grains
# frame_00199.jpg: 4 grains
# frame_00200.jpg: 10 grains
# frame_00201.jpg: 0 grains
# frame_00202.jpg: 5 grains
# frame_00203.jpg: 1 grains
# frame_00204.jpg: 1 grains
# frame_00205.jpg: 8 grains
# frame_00206.jpg: 3 grains
# frame_00207.jpg: 2 grains
# frame_00208.jpg: 1 grains
# frame_00209.jpg: 0 grains
# frame_00210.jpg: 5 grains
# frame_00211.jpg: 5 grains
# frame_00212.jpg: 2 grains
# frame_00213.jpg: 0 grains
# frame_00214.jpg: 1 grains
# frame_00215.jpg: 1 grains
# frame_00216.jpg: 4 grains
# frame_00217.jpg: 4 grains
# frame_00218.jpg: 1 grains
# frame_00219.jpg: 0 grains
# frame_00220.jpg: 2 grains
# frame_00221.jpg: 1 grains
# frame_00222.jpg: 3 grains
# frame_00223.jpg: 6 grains
# frame_00224.jpg: 1 grains
# frame_00225.jpg: 0 grains
# frame_00226.jpg: 1 grains
# frame_00227.jpg: 0 grains
# frame_00228.jpg: 7 grains
# frame_00229.jpg: 3 grains
# frame_00230.jpg: 0 grains
# frame_00231.jpg: 1 grains
# frame_00232.jpg: 1 grains
# frame_00233.jpg: 1 grains
# frame_00234.jpg: 2 grains
# frame_00235.jpg: 3 grains
# frame_00236.jpg: 1 grains
# frame_00237.jpg: 6 grains
# frame_00238.jpg: 1 grains
# frame_00239.jpg: 1 grains
# frame_00240.jpg: 7 grains
# frame_00241.jpg: 5 grains
# frame_00242.jpg: 6 grains
# frame_00243.jpg: 2 grains
# frame_00244.jpg: 1 grains
# frame_00245.jpg: 7 grains
# frame_00246.jpg: 3 grains
# frame_00247.jpg: 2 grains
# frame_00248.jpg: 4 grains
# frame_00249.jpg: 0 grains
# frame_00250.jpg: 10 grains
# frame_00251.jpg: 4 grains
# frame_00252.jpg: 0 grains
# frame_00253.jpg: 4 grains
# frame_00254.jpg: 2 grains
# frame_00255.jpg: 4 grains
# frame_00256.jpg: 7 grains
# frame_00257.jpg: 3 grains
# frame_00258.jpg: 3 grains
# frame_00259.jpg: 4 grains
# frame_00260.jpg: 3 grains
# frame_00261.jpg: 7 grains
# frame_00262.jpg: 1 grains
# frame_00263.jpg: 2 grains
# frame_00264.jpg: 3 grains
# frame_00265.jpg: 3 grains
# frame_00266.jpg: 0 grains
# frame_00267.jpg: 4 grains
# frame_00268.jpg: 0 grains
# frame_00269.jpg: 2 grains
# frame_00270.jpg: 1 grains
# frame_00271.jpg: 0 grains
# frame_00272.jpg: 3 grains
# frame_00273.jpg: 2 grains
# frame_00274.jpg: 2 grains
# frame_00275.jpg: 0 grains
# frame_00276.jpg: 2 grains
# frame_00277.jpg: 2 grains
# frame_00278.jpg: 2 grains
# frame_00279.jpg: 0 grains
# frame_00280.jpg: 0 grains
# frame_00281.jpg: 1 grains
# frame_00282.jpg: 1 grains
# frame_00283.jpg: 1 grains
# frame_00284.jpg: 1 grains
# frame_00285.jpg: 4 grains
# frame_00286.jpg: 2 grains
# frame_00287.jpg: 4 grains
# frame_00288.jpg: 0 grains
# frame_00289.jpg: 7 grains
# frame_00290.jpg: 5 grains
# frame_00291.jpg: 5 grains
# frame_00292.jpg: 3 grains
# frame_00293.jpg: 4 grains
# frame_00294.jpg: 6 grains
# frame_00295.jpg: 2 grains
# frame_00296.jpg: 3 grains
# frame_00297.jpg: 3 grains
# frame_00298.jpg: 2 grains
# frame_00299.jpg: 2 grains
# frame_00300.jpg: 5 grains
# frame_00301.jpg: 6 grains
# frame_00302.jpg: 5 grains
# frame_00303.jpg: 6 grains
# frame_00304.jpg: 1 grains
# frame_00305.jpg: 4 grains
# frame_00306.jpg: 3 grains
# frame_00307.jpg: 0 grains
# frame_00308.jpg: 1 grains
# frame_00309.jpg: 0 grains
# frame_00310.jpg: 2 grains
# frame_00311.jpg: 2 grains
# frame_00312.jpg: 0 grains
# frame_00313.jpg: 6 grains
# frame_00314.jpg: 9 grains
# frame_00315.jpg: 2 grains
# frame_00316.jpg: 4 grains
# frame_00317.jpg: 21 grains
# frame_00318.jpg: 18 grains
# frame_00319.jpg: 14 grains
# frame_00320.jpg: 15 grains
# frame_00321.jpg: 6 grains
# frame_00322.jpg: 5 grains
# frame_00323.jpg: 2 grains
# frame_00324.jpg: 1 grains
# frame_00325.jpg: 2 grains
# frame_00326.jpg: 10 grains
# frame_00327.jpg: 18 grains
# frame_00328.jpg: 11 grains
# frame_00329.jpg: 8 grains
# frame_00330.jpg: 2 grains
# frame_00331.jpg: 3 grains
# frame_00332.jpg: 0 grains
# frame_00333.jpg: 0 grains
# frame_00334.jpg: 0 grains
# frame_00335.jpg: 1 grains
# frame_00336.jpg: 2 grains
# frame_00337.jpg: 2 grains
# frame_00338.jpg: 5 grains
# frame_00339.jpg: 1 grains
# frame_00340.jpg: 0 grains
# frame_00341.jpg: 0 grains
# frame_00342.jpg: 0 grains
# frame_00343.jpg: 0 grains
# frame_00344.jpg: 0 grains
# frame_00345.jpg: 0 grains
# frame_00346.jpg: 0 grains
# frame_00347.jpg: 0 grains
# frame_00348.jpg: 0 grains
# frame_00349.jpg: 1 grains
# frame_00350.jpg: 3 grains
# frame_00351.jpg: 2 grains
# frame_00352.jpg: 15 grains
# frame_00353.jpg: 14 grains
# frame_00354.jpg: 7 grains
# frame_00355.jpg: 16 grains
# frame_00356.jpg: 16 grains
# frame_00357.jpg: 8 grains
# frame_00358.jpg: 4 grains
# frame_00359.jpg: 10 grains
# frame_00360.jpg: 8 grains
# frame_00361.jpg: 6 grains
# frame_00362.jpg: 6 grains
# frame_00363.jpg: 6 grains
# frame_00364.jpg: 4 grains
# frame_00365.jpg: 4 grains
# frame_00366.jpg: 4 grains
# frame_00367.jpg: 6 grains
# frame_00368.jpg: 10 grains
# frame_00369.jpg: 7 grains
# frame_00370.jpg: 5 grains
# frame_00371.jpg: 2 grains
# frame_00372.jpg: 2 grains
# frame_00373.jpg: 1 grains
# frame_00374.jpg: 0 grains
# frame_00375.jpg: 5 grains
# frame_00376.jpg: 9 grains
# frame_00377.jpg: 2 grains
# frame_00378.jpg: 9 grains
# frame_00379.jpg: 4 grains
# frame_00380.jpg: 8 grains
# frame_00381.jpg: 10 grains
# frame_00382.jpg: 5 grains
# frame_00383.jpg: 2 grains
# frame_00384.jpg: 4 grains
# frame_00385.jpg: 6 grains
# frame_00386.jpg: 16 grains
# frame_00387.jpg: 10 grains
# frame_00388.jpg: 9 grains
# frame_00389.jpg: 5 grains
# frame_00390.jpg: 4 grains
# frame_00391.jpg: 5 grains
# frame_00392.jpg: 0 grains
# frame_00393.jpg: 1 grains
# frame_00394.jpg: 2 grains
# frame_00395.jpg: 1 grains
# frame_00396.jpg: 1 grains
# frame_00397.jpg: 2 grains
# frame_00398.jpg: 1 grains
# frame_00399.jpg: 1 grains
# frame_00400.jpg: 1 grains
# frame_00401.jpg: 1 grains
# frame_00402.jpg: 7 grains
# frame_00403.jpg: 8 grains
# frame_00404.jpg: 2 grains
# frame_00405.jpg: 5 grains
# frame_00406.jpg: 6 grains
# frame_00407.jpg: 5 grains
# frame_00408.jpg: 5 grains
# frame_00409.jpg: 2 grains
# frame_00410.jpg: 3 grains
# frame_00411.jpg: 8 grains
# frame_00412.jpg: 6 grains
# frame_00413.jpg: 1 grains
# frame_00414.jpg: 4 grains
# frame_00415.jpg: 2 grains
# frame_00416.jpg: 3 grains
# frame_00417.jpg: 3 grains
# frame_00418.jpg: 5 grains
# frame_00419.jpg: 2 grains
# frame_00420.jpg: 2 grains
# frame_00421.jpg: 0 grains
# frame_00422.jpg: 1 grains
# frame_00423.jpg: 1 grains
# frame_00424.jpg: 0 grains
# frame_00425.jpg: 0 grains
# frame_00426.jpg: 3 grains
# frame_00427.jpg: 2 grains
# frame_00428.jpg: 0 grains
# frame_00429.jpg: 0 grains
# frame_00430.jpg: 11 grains
# frame_00431.jpg: 5 grains
# frame_00432.jpg: 4 grains
# frame_00433.jpg: 3 grains
# frame_00434.jpg: 6 grains
# frame_00435.jpg: 0 grains
# frame_00436.jpg: 5 grains
# frame_00437.jpg: 4 grains
# frame_00438.jpg: 4 grains
# frame_00439.jpg: 9 grains
# frame_00440.jpg: 1 grains
# frame_00441.jpg: 10 grains
# frame_00442.jpg: 3 grains
# frame_00443.jpg: 5 grains
# frame_00444.jpg: 3 grains
# frame_00445.jpg: 0 grains
# frame_00446.jpg: 5 grains
# frame_00447.jpg: 1 grains
# frame_00448.jpg: 5 grains
# frame_00449.jpg: 8 grains
# frame_00450.jpg: 4 grains
# frame_00451.jpg: 3 grains
# frame_00452.jpg: 4 grains
# frame_00453.jpg: 0 grains
# frame_00454.jpg: 3 grains
# frame_00455.jpg: 0 grains
# frame_00456.jpg: 4 grains
# frame_00457.jpg: 3 grains
# frame_00458.jpg: 4 grains
# frame_00459.jpg: 10 grains
# frame_00460.jpg: 2 grains
# frame_00461.jpg: 6 grains
# frame_00462.jpg: 1 grains
# frame_00463.jpg: 9 grains
# frame_00464.jpg: 5 grains
# frame_00465.jpg: 1 grains
# frame_00466.jpg: 4 grains
# frame_00467.jpg: 3 grains
# frame_00468.jpg: 2 grains
# frame_00469.jpg: 4 grains
# frame_00470.jpg: 3 grains
# frame_00471.jpg: 1 grains
# frame_00472.jpg: 3 grains
# frame_00473.jpg: 2 grains
# frame_00474.jpg: 1 grains
# frame_00475.jpg: 3 grains
# frame_00476.jpg: 1 grains
# frame_00477.jpg: 1 grains
# frame_00478.jpg: 5 grains
# frame_00479.jpg: 1 grains
# frame_00480.jpg: 1 grains
# frame_00481.jpg: 5 grains
# frame_00482.jpg: 4 grains
# frame_00483.jpg: 3 grains
# frame_00484.jpg: 4 grains
# frame_00485.jpg: 1 grains
# frame_00486.jpg: 5 grains
# frame_00487.jpg: 1 grains
# frame_00488.jpg: 1 grains
# frame_00489.jpg: 1 grains
# frame_00490.jpg: 0 grains
# frame_00491.jpg: 0 grains
# frame_00492.jpg: 0 grains
# frame_00493.jpg: 0 grains
# frame_00494.jpg: 0 grains
# frame_00495.jpg: 2 grains
# frame_00496.jpg: 3 grains
# frame_00497.jpg: 4 grains
# frame_00498.jpg: 5 grains
# frame_00499.jpg: 2 grains
# frame_00500.jpg: 4 grains
# frame_00501.jpg: 2 grains
# frame_00502.jpg: 6 grains
# frame_00503.jpg: 1 grains
# frame_00504.jpg: 2 grains
# frame_00505.jpg: 0 grains
# frame_00506.jpg: 2 grains
# frame_00507.jpg: 0 grains
# frame_00508.jpg: 0 grains
# frame_00509.jpg: 0 grains
# frame_00510.jpg: 0 grains
# frame_00511.jpg: 2 grains
# frame_00512.jpg: 2 grains
# frame_00513.jpg: 6 grains
# frame_00514.jpg: 3 grains
# frame_00515.jpg: 5 grains
# frame_00516.jpg: 3 grains
# frame_00517.jpg: 10 grains
# frame_00518.jpg: 13 grains
# frame_00519.jpg: 5 grains
# frame_00520.jpg: 2 grains
# frame_00521.jpg: 3 grains
# frame_00522.jpg: 1 grains
# frame_00523.jpg: 8 grains
# frame_00524.jpg: 2 grains
# frame_00525.jpg: 0 grains
# frame_00526.jpg: 0 grains
# frame_00527.jpg: 3 grains
# frame_00528.jpg: 0 grains
# frame_00529.jpg: 5 grains
# frame_00530.jpg: 5 grains
# frame_00531.jpg: 2 grains
# frame_00532.jpg: 7 grains
# frame_00533.jpg: 4 grains
# frame_00534.jpg: 5 grains
# frame_00535.jpg: 12 grains
# frame_00536.jpg: 1 grains
# frame_00537.jpg: 0 grains
# frame_00538.jpg: 1 grains
# frame_00539.jpg: 3 grains
# frame_00540.jpg: 2 grains
# frame_00541.jpg: 0 grains
# frame_00542.jpg: 5 grains
# frame_00543.jpg: 1 grains
# frame_00544.jpg: 2 grains
# frame_00545.jpg: 6 grains
# frame_00546.jpg: 1 grains
# frame_00547.jpg: 7 grains
# frame_00548.jpg: 7 grains
# frame_00549.jpg: 5 grains
# frame_00550.jpg: 6 grains
# frame_00551.jpg: 2 grains
# frame_00552.jpg: 1 grains
# frame_00553.jpg: 1 grains
# frame_00554.jpg: 0 grains
# frame_00555.jpg: 4 grains
# frame_00556.jpg: 1 grains
# frame_00557.jpg: 2 grains
# frame_00558.jpg: 3 grains
# frame_00559.jpg: 3 grains
# frame_00560.jpg: 1 grains
# frame_00561.jpg: 2 grains
# frame_00562.jpg: 5 grains
# frame_00563.jpg: 3 grains
# frame_00564.jpg: 1 grains
# frame_00565.jpg: 1 grains
# frame_00566.jpg: 2 grains
# frame_00567.jpg: 4 grains
# frame_00568.jpg: 1 grains
# frame_00569.jpg: 2 grains
# frame_00570.jpg: 1 grains
# frame_00571.jpg: 1 grains
# frame_00572.jpg: 5 grains
# frame_00573.jpg: 1 grains
# frame_00574.jpg: 6 grains
# frame_00575.jpg: 2 grains
# frame_00576.jpg: 2 grains
# frame_00577.jpg: 2 grains
# frame_00578.jpg: 1 grains
# frame_00579.jpg: 0 grains
# frame_00580.jpg: 3 grains
# frame_00581.jpg: 1 grains
# frame_00582.jpg: 1 grains
# frame_00583.jpg: 0 grains
# frame_00584.jpg: 1 grains
# frame_00585.jpg: 6 grains
# frame_00586.jpg: 0 grains
# frame_00587.jpg: 1 grains
# frame_00588.jpg: 1 grains
# frame_00589.jpg: 5 grains
# frame_00590.jpg: 2 grains
# frame_00591.jpg: 1 grains
# frame_00592.jpg: 1 grains
# frame_00593.jpg: 3 grains
# frame_00594.jpg: 0 grains
# frame_00595.jpg: 0 grains
# frame_00596.jpg: 0 grains
# frame_00597.jpg: 0 grains
# frame_00598.jpg: 0 grains
# frame_00599.jpg: 0 grains
# frame_00600.jpg: 0 grains
# frame_00601.jpg: 1 grains
# frame_00602.jpg: 0 grains
# frame_00603.jpg: 1 grains
# frame_00604.jpg: 0 grains
# frame_00605.jpg: 2 grains
# frame_00606.jpg: 0 grains
# frame_00607.jpg: 0 grains
# frame_00608.jpg: 1 grains
# frame_00609.jpg: 1 grains
# frame_00610.jpg: 0 grains
# frame_00611.jpg: 0 grains
# frame_00612.jpg: 0 grains
# frame_00613.jpg: 0 grains
# frame_00614.jpg: 0 grains
# frame_00615.jpg: 0 grains
# frame_00616.jpg: 1 grains
# frame_00617.jpg: 0 grains
# frame_00618.jpg: 0 grains
# frame_00619.jpg: 0 grains
# frame_00620.jpg: 0 grains
# frame_00621.jpg: 0 grains
# frame_00622.jpg: 0 grains
# frame_00623.jpg: 1 grains
# frame_00624.jpg: 0 grains
# frame_00625.jpg: 1 grains
# frame_00626.jpg: 0 grains
# frame_00627.jpg: 0 grains
# frame_00628.jpg: 0 grains
# frame_00629.jpg: 2 grains
# frame_00630.jpg: 1 grains
# frame_00631.jpg: 1 grains
# frame_00632.jpg: 0 grains
# frame_00633.jpg: 1 grains
# frame_00634.jpg: 3 grains
# frame_00635.jpg: 1 grains
# frame_00636.jpg: 1 grains
# frame_00637.jpg: 0 grains
# frame_00638.jpg: 0 grains
# frame_00639.jpg: 1 grains
# frame_00640.jpg: 0 grains
# frame_00641.jpg: 0 grains
# frame_00642.jpg: 2 grains
# frame_00643.jpg: 1 grains
# frame_00644.jpg: 0 grains
# frame_00645.jpg: 0 grains
# frame_00646.jpg: 2 grains
# frame_00647.jpg: 0 grains
# frame_00648.jpg: 0 grains
# frame_00649.jpg: 1 grains
# frame_00650.jpg: 2 grains
# frame_00651.jpg: 2 grains
# frame_00652.jpg: 2 grains
# frame_00653.jpg: 0 grains
# frame_00654.jpg: 2 grains
# frame_00655.jpg: 0 grains
# frame_00656.jpg: 0 grains
# frame_00657.jpg: 0 grains
# frame_00658.jpg: 3 grains
# frame_00659.jpg: 1 grains
# frame_00660.jpg: 2 grains
# frame_00661.jpg: 0 grains
# frame_00662.jpg: 0 grains
# frame_00663.jpg: 2 grains
# frame_00664.jpg: 0 grains
# frame_00665.jpg: 2 grains
# frame_00666.jpg: 1 grains
# frame_00667.jpg: 2 grains
# frame_00668.jpg: 2 grains
# frame_00669.jpg: 1 grains
# frame_00670.jpg: 0 grains
# frame_00671.jpg: 0 grains
# frame_00672.jpg: 1 grains
# frame_00673.jpg: 2 grains
# frame_00674.jpg: 1 grains
# frame_00675.jpg: 2 grains
# frame_00676.jpg: 1 grains
# frame_00677.jpg: 0 grains
# frame_00678.jpg: 1 grains
# frame_00679.jpg: 0 grains
# frame_00680.jpg: 0 grains
# frame_00681.jpg: 0 grains
# frame_00682.jpg: 1 grains
# frame_00683.jpg: 0 grains
# frame_00684.jpg: 0 grains
# frame_00685.jpg: 0 grains
# frame_00686.jpg: 0 grains
# frame_00687.jpg: 0 grains
# frame_00688.jpg: 1 grains
# frame_00689.jpg: 2 grains
# frame_00690.jpg: 0 grains
# frame_00691.jpg: 1 grains
# frame_00692.jpg: 7 grains
# frame_00693.jpg: 19 grains
# frame_00694.jpg: 19 grains
# frame_00695.jpg: 2 grains
# frame_00696.jpg: 6 grains
# frame_00697.jpg: 3 grains
# frame_00698.jpg: 2 grains
# frame_00699.jpg: 1 grains
# frame_00700.jpg: 0 grains
# frame_00701.jpg: 0 grains
# frame_00702.jpg: 0 grains
# frame_00703.jpg: 2 grains
# frame_00704.jpg: 3 grains
# frame_00705.jpg: 2 grains
# frame_00706.jpg: 2 grains
# frame_00707.jpg: 5 grains
# frame_00708.jpg: 3 grains
# frame_00709.jpg: 2 grains
# frame_00710.jpg: 0 grains
# frame_00711.jpg: 0 grains
# frame_00712.jpg: 0 grains
# frame_00713.jpg: 0 grains
# frame_00714.jpg: 0 grains
# frame_00715.jpg: 0 grains
# frame_00716.jpg: 2 grains
# frame_00717.jpg: 1 grains
# frame_00718.jpg: 1 grains
# frame_00719.jpg: 0 grains
# frame_00720.jpg: 2 grains
# frame_00721.jpg: 1 grains
# frame_00722.jpg: 1 grains
# frame_00723.jpg: 0 grains
# frame_00724.jpg: 0 grains
# frame_00725.jpg: 0 grains
# frame_00726.jpg: 1 grains
# frame_00727.jpg: 1 grains
# frame_00728.jpg: 0 grains
# frame_00729.jpg: 0 grains
# frame_00730.jpg: 2 grains
# frame_00731.jpg: 1 grains
# frame_00732.jpg: 1 grains
# frame_00733.jpg: 2 grains
# frame_00734.jpg: 3 grains
# frame_00735.jpg: 2 grains
# frame_00736.jpg: 1 grains
# frame_00737.jpg: 2 grains
# frame_00738.jpg: 1 grains
# frame_00739.jpg: 2 grains
# frame_00740.jpg: 2 grains
# frame_00741.jpg: 2 grains
# frame_00742.jpg: 3 grains
# frame_00743.jpg: 1 grains
# frame_00744.jpg: 2 grains
# frame_00745.jpg: 3 grains
# frame_00746.jpg: 0 grains
# frame_00747.jpg: 6 grains
#
# Total rice grains from all images: 2065
